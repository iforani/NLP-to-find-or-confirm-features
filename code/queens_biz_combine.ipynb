# %%
import numpy as np
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Cam\\Data Science\\DSI\\capstone'

# %%
os.chdir('./queens/')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Cam\\Data Science\\DSI\\capstone\\queens'

# %%
files = os.listdir()[2:]

# %%
files
# Out:
# ['queens_11004.csv',
#  'queens_11005.csv',
#  'queens_11101.csv',
#  'queens_11102.csv',
#  'queens_11103.csv',
#  'queens_11104.csv',
#  'queens_11105.csv',
#  'queens_11106.csv',
#  'queens_11354.csv',
#  'queens_11355.csv',
#  'queens_11356.csv',
#  'queens_11357.csv',
#  'queens_11358.csv',
#  'queens_11359.csv',
#  'queens_11360.csv',
#  'queens_11361.csv',
#  'queens_11362.csv',
#  'queens_11363.csv',
#  'queens_11364.csv',
#  'queens_11365.csv',
#  'queens_11366.csv',
#  'queens_11367.csv',
#  'queens_11368.csv',
#  'queens_11369.csv',
#  'queens_11370.csv',
#  'queens_11372.csv',
#  'queens_11373.csv',
#  'queens_11374.csv',
#  'queens_11375.csv',
#  'queens_11377.csv',
#  'queens_11378.csv',
#  'queens_11379.csv',
#  'queens_11385.csv',
#  'queens_11411.csv',
#  'queens_11412.csv',
#  'queens_11413.csv',
#  'queens_11414.csv',
#  'queens_11415.csv',
#  'queens_11416.csv',
#  'queens_11417.csv',
#  'queens_11418.csv',
#  'queens_11419.csv',
#  'queens_11420.csv',
# ...

# %%
queens_bizs = [pd.read_csv(file) for file in files]

# %%
queens_bizs
# Out:
# [                               name  \
#  0                          K. Pacho
#  1        Majlis Restaurant & Lounge
#  2            Remedy Lounge and Cafe
#  3                  Cajun Crab Shack
#  4                        Brew House
#  5                        Elsie Lane
#  6          Trinity Restaurant & Bar
#  7              Al Nar Hookah Lounge
#  8   Cabo Sports bar & Mexican Grill
#  9    Sohna Punjab Indian Restaurant
#  10                Charlie Bullfrogs
#  11                    Moonlight Pub
#  12                   Pegasus Lounge
#  13        Midas Hookah Lounge & Bar
#  14                Towers Restaurant
#  15                     Winchester's
#  16                      Rivers Cafe
#  17                      The Stadium
#  18         Nap TIme Liquid Creation
#
#                                                  alias                      id  \
#  0                               k-pacho-new-hyde-park  hcMoQDajkgihtGgNwL7k6w
# ...

# %%
all_queens = pd.DataFrame()
for frame in queens_bizs:
    all_queens = all_queens.append(frame)
all_queens
# Out:
#                           name                                     alias  \
# 0                     K. Pacho                     k-pacho-new-hyde-park
# 1   Majlis Restaurant & Lounge  majlis-restaurant-and-lounge-bellerose-2
# 2       Remedy Lounge and Cafe          remedy-lounge-and-cafe-bellerose
# 3             Cajun Crab Shack              cajun-crab-shack-floral-park
# 4                   Brew House                  brew-house-new-hyde-park
# ..                         ...                                       ...
# 15        Tamaqua Bar & Marina           tamaqua-bar-and-marina-brooklyn
# 16        Penthouse Lounge Bar             penthouse-lounge-bar-brooklyn
# 17            Night Light Cafe                 night-light-cafe-brooklyn
# 18           Duff on the Rocks              duff-on-the-rocks-new-york-2
# 19    Nap TIme Liquid Creation         nap-time-liquid-creation-blauvelt
#
#                         id  review_count  rating  \
# ...

# %%
all_queens.reset_index(inplace=True, drop=True)

# %%
all_queens
# Out:
#                             name                                     alias  \
# 0                       K. Pacho                     k-pacho-new-hyde-park
# 1     Majlis Restaurant & Lounge  majlis-restaurant-and-lounge-bellerose-2
# 2         Remedy Lounge and Cafe          remedy-lounge-and-cafe-bellerose
# 3               Cajun Crab Shack              cajun-crab-shack-floral-park
# 4                     Brew House                  brew-house-new-hyde-park
# ...                          ...                                       ...
# 4476        Tamaqua Bar & Marina           tamaqua-bar-and-marina-brooklyn
# 4477        Penthouse Lounge Bar             penthouse-lounge-bar-brooklyn
# 4478            Night Light Cafe                 night-light-cafe-brooklyn
# 4479           Duff on the Rocks              duff-on-the-rocks-new-york-2
# 4480    Nap TIme Liquid Creation         nap-time-liquid-creation-blauvelt
#
#                           id  review_count  rating  \
# ...

# %%
all_queens.columns
# Out:
# Index(['name', 'alias', 'id', 'review_count', 'rating', 'url', 'location',
#        'coordinates'],
#       dtype='object')

# %%
all_queens['id'].nunique()
# Out:
# 1832

# %%
all_queens['name'].nunique()
# Out:
# 1796

# %%
all_queens['alias'].nunique()
# Out:
# 1832

# %%
all_queens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4481 entries, 0 to 4480
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          4481 non-null   object
#  1   alias         4481 non-null   object
#  2   id            4481 non-null   object
#  3   review_count  4481 non-null   int64
#  4   rating        4481 non-null   float64
#  5   url           4481 non-null   object
#  6   location      4481 non-null   object
#  7   coordinates   4481 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 280.2+ KB

# %%
len(all_queens['id'].unique())
# Out:
# 1832

# %%
all_queens.drop_duplicates(subset='id', inplace = True)

# %%
all_queens['id'].nunique()
# Out:
# 1832

# %%
all_queens['name'].nunique()
# Out:
# 1796

# %%
all_queens['alias'].nunique()
# Out:
# 1832

# %%
all_queens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1832 entries, 0 to 4478
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          1832 non-null   object
#  1   alias         1832 non-null   object
#  2   id            1832 non-null   object
#  3   review_count  1832 non-null   int64
#  4   rating        1832 non-null   float64
#  5   url           1832 non-null   object
#  6   location      1832 non-null   object
#  7   coordinates   1832 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 128.8+ KB

# %%
len(all_queens['id'].unique())
# Out:
# 1832

# %%
all_queens
# Out:
#                               name                                      alias  \
# 0                         K. Pacho                      k-pacho-new-hyde-park
# 1       Majlis Restaurant & Lounge   majlis-restaurant-and-lounge-bellerose-2
# 2           Remedy Lounge and Cafe           remedy-lounge-and-cafe-bellerose
# 3                 Cajun Crab Shack               cajun-crab-shack-floral-park
# 4                       Brew House                   brew-house-new-hyde-park
# ...                            ...                                        ...
# 4471                 Falada Lounge                     falada-lounge-brooklyn
# 4472  End Zone Sports Bar & Lounge  end-zone-sports-bar-and-lounge-brooklyn-2
# 4473                      Tap Beer                        tap-beer-brooklyn-4
# 4477          Penthouse Lounge Bar              penthouse-lounge-bar-brooklyn
# 4478              Night Light Cafe                  night-light-cafe-brooklyn
#
# ...

# %%
all_queens.reset_index(inplace = True, drop=True)

# %%
all_queens
# Out:
#                               name                                      alias  \
# 0                         K. Pacho                      k-pacho-new-hyde-park
# 1       Majlis Restaurant & Lounge   majlis-restaurant-and-lounge-bellerose-2
# 2           Remedy Lounge and Cafe           remedy-lounge-and-cafe-bellerose
# 3                 Cajun Crab Shack               cajun-crab-shack-floral-park
# 4                       Brew House                   brew-house-new-hyde-park
# ...                            ...                                        ...
# 1827                 Falada Lounge                     falada-lounge-brooklyn
# 1828  End Zone Sports Bar & Lounge  end-zone-sports-bar-and-lounge-brooklyn-2
# 1829                      Tap Beer                        tap-beer-brooklyn-4
# 1830          Penthouse Lounge Bar              penthouse-lounge-bar-brooklyn
# 1831              Night Light Cafe                  night-light-cafe-brooklyn
#
# ...

# %%
all_queens.to_csv('all_queens_bizs.csv', index=False)
