# %%
import pandas as pd

# %%
bk_biz = pd.read_csv('./brooklyn/all_bk_bizs.csv')
bk_biz
# Out:
#                         name                                 alias  \
# 0                Forno Rosso                  forno-rosso-brooklyn
# 1     Two 8 Two Bar & Burger     two-8-two-bar-and-burger-brooklyn
# 2             The River Café             the-river-café-brooklyn-3
# 3                    Colonie                      colonie-brooklyn
# 4                   Chez Moi                     chez-moi-brooklyn
# ...                      ...                                   ...
# 1820            The Live Oak                the-live-oak-maspeth-2
# 1821        Knockdown Center              knockdown-center-maspeth
# 1822                 Chasers                    chasers-new-york-2
# 1823          Peggy Dempseys                peggy-dempseys-maspeth
# 1824   Club House Sports Bar  club-house-sports-bar-middle-village
#
#                           id  review_count  rating  \
# 0     ZTsN8TdMXl8SW_AKd_ablw           681     4.0
# 1     xiEBdZ8z5KY21Vw2pY2fJQ           662     4.0
# ...

# %%
qns_biz = pd.read_csv('./queens/all_queens_bizs.csv')
qns_biz
# Out:
#                               name                                      alias  \
# 0                         K. Pacho                      k-pacho-new-hyde-park
# 1       Majlis Restaurant & Lounge   majlis-restaurant-and-lounge-bellerose-2
# 2           Remedy Lounge and Cafe           remedy-lounge-and-cafe-bellerose
# 3                 Cajun Crab Shack               cajun-crab-shack-floral-park
# 4                       Brew House                   brew-house-new-hyde-park
# ...                            ...                                        ...
# 1827                 Falada Lounge                     falada-lounge-brooklyn
# 1828  End Zone Sports Bar & Lounge  end-zone-sports-bar-and-lounge-brooklyn-2
# 1829                      Tap Beer                        tap-beer-brooklyn-4
# 1830          Penthouse Lounge Bar              penthouse-lounge-bar-brooklyn
# 1831              Night Light Cafe                  night-light-cafe-brooklyn
#
# ...

# %%
combined = qns_biz.append(bk_biz)
combined
# Out:
#                             name                                     alias  \
# 0                       K. Pacho                     k-pacho-new-hyde-park
# 1     Majlis Restaurant & Lounge  majlis-restaurant-and-lounge-bellerose-2
# 2         Remedy Lounge and Cafe          remedy-lounge-and-cafe-bellerose
# 3               Cajun Crab Shack              cajun-crab-shack-floral-park
# 4                     Brew House                  brew-house-new-hyde-park
# ...                          ...                                       ...
# 1820                The Live Oak                    the-live-oak-maspeth-2
# 1821            Knockdown Center                  knockdown-center-maspeth
# 1822                     Chasers                        chasers-new-york-2
# 1823              Peggy Dempseys                    peggy-dempseys-maspeth
# 1824       Club House Sports Bar      club-house-sports-bar-middle-village
#
#                           id  review_count  rating  \
# ...

# %%
combined['id'].nunique()
# Out:
# 2889

# %% [markdown]
# --BK on bottom
#
# --Keep Last
#
# --Train on Queens

# %%
combined.drop_duplicates(subset='id', keep='last', inplace=True)

# %% [markdown]
# queens original count 1832
#
# combined 3657
#
# unique 2889

# %%
3657 - 2889
# Out:
# 768

# %%
1832 - 768
# Out:
# 1064

# %%
combined[1060:1080]
# Out:
#                                            name  \
# 1813                               Jamesons Pub
# 1815                               The Bayhouse
# 1817                             The Sugar Bowl
# 1818                             Blarney Castle
# 0                                   Forno Rosso
# 1                        Two 8 Two Bar & Burger
# 2                                The River Café
# 3                                       Colonie
# 4                                      Chez Moi
# 5                                   Henry's End
# 6                               The Dead Rabbit
# 7                                 Circa Brewing
# 8     Alamo Drafthouse Cinema Downtown Brooklyn
# 9                                   Clover Club
# 10                                      Bijan's
# 11                           Kesté Pizza & Vino
# 12                                 Dellarocco's
# 13                          Adrienne's Pizzabar
# ...

# %%
qns_split = combined[:1064]

# %%
qns_split
# Out:
#                             name                                     alias  \
# 0                       K. Pacho                     k-pacho-new-hyde-park
# 1     Majlis Restaurant & Lounge  majlis-restaurant-and-lounge-bellerose-2
# 2         Remedy Lounge and Cafe          remedy-lounge-and-cafe-bellerose
# 3               Cajun Crab Shack              cajun-crab-shack-floral-park
# 4                     Brew House                  brew-house-new-hyde-park
# ...                          ...                                       ...
# 1812            Harbor Light Pub            harbor-light-pub-rockaway-park
# 1813                Jamesons Pub                jamesons-pub-rockaway-park
# 1815                The Bayhouse                 the-bayhouse-breezy-point
# 1817              The Sugar Bowl               the-sugar-bowl-breezy-point
# 1818              Blarney Castle             blarney-castle-breezy-point-2
#
#                           id  review_count  rating  \
# ...

# %%
qns_split.reset_index(drop=True, inplace=True)
qns_split
# Out:
#                             name                                     alias  \
# 0                       K. Pacho                     k-pacho-new-hyde-park
# 1     Majlis Restaurant & Lounge  majlis-restaurant-and-lounge-bellerose-2
# 2         Remedy Lounge and Cafe          remedy-lounge-and-cafe-bellerose
# 3               Cajun Crab Shack              cajun-crab-shack-floral-park
# 4                     Brew House                  brew-house-new-hyde-park
# ...                          ...                                       ...
# 1059            Harbor Light Pub            harbor-light-pub-rockaway-park
# 1060                Jamesons Pub                jamesons-pub-rockaway-park
# 1061                The Bayhouse                 the-bayhouse-breezy-point
# 1062              The Sugar Bowl               the-sugar-bowl-breezy-point
# 1063              Blarney Castle             blarney-castle-breezy-point-2
#
#                           id  review_count  rating  \
# ...

# %%
qns_split.describe()
# Out:
#        review_count       rating
# count   1064.000000  1064.000000
# mean     203.684211     3.654605
# std      305.877628     0.797643
# min        1.000000     1.000000
# 25%       18.000000     3.500000
# 50%       91.000000     4.000000
# 75%      254.250000     4.000000
# max     2668.000000     5.000000

# %%
qns_split[qns_split['review_count'] > 20]
# Out:
#                             name                                     alias  \
# 0                       K. Pacho                     k-pacho-new-hyde-park
# 1     Majlis Restaurant & Lounge  majlis-restaurant-and-lounge-bellerose-2
# 2         Remedy Lounge and Cafe          remedy-lounge-and-cafe-bellerose
# 3               Cajun Crab Shack              cajun-crab-shack-floral-park
# 4                     Brew House                  brew-house-new-hyde-park
# ...                          ...                                       ...
# 1052                Low Tide Bar                     low-tide-bar-rockaway
# 1057       The Wharf Bar & Grill     the-wharf-bar-and-grill-rockaway-park
# 1058                        Pico                             pico-rockaway
# 1060                Jamesons Pub                jamesons-pub-rockaway-park
# 1061                The Bayhouse                 the-bayhouse-breezy-point
#
#                           id  review_count  rating  \
# ...

# %%
qns_split = qns_split[qns_split['review_count'] > 20]

# %%
qns_split.reset_index(drop=True, inplace=True)

# %%
qns_split
# Out:
#                            name                                     alias  \
# 0                      K. Pacho                     k-pacho-new-hyde-park
# 1    Majlis Restaurant & Lounge  majlis-restaurant-and-lounge-bellerose-2
# 2        Remedy Lounge and Cafe          remedy-lounge-and-cafe-bellerose
# 3              Cajun Crab Shack              cajun-crab-shack-floral-park
# 4                    Brew House                  brew-house-new-hyde-park
# ..                          ...                                       ...
# 778                Low Tide Bar                     low-tide-bar-rockaway
# 779       The Wharf Bar & Grill     the-wharf-bar-and-grill-rockaway-park
# 780                        Pico                             pico-rockaway
# 781                Jamesons Pub                jamesons-pub-rockaway-park
# 782                The Bayhouse                 the-bayhouse-breezy-point
#
#                          id  review_count  rating  \
# ...

# %%
qns_split.to_csv('./queens/final_queens_biz.csv', index=False)

# %%
bk_split = combined[1064:]
bk_split
# Out:
#                         name                                 alias  \
# 0                Forno Rosso                  forno-rosso-brooklyn
# 1     Two 8 Two Bar & Burger     two-8-two-bar-and-burger-brooklyn
# 2             The River Café             the-river-café-brooklyn-3
# 3                    Colonie                      colonie-brooklyn
# 4                   Chez Moi                     chez-moi-brooklyn
# ...                      ...                                   ...
# 1820            The Live Oak                the-live-oak-maspeth-2
# 1821        Knockdown Center              knockdown-center-maspeth
# 1822                 Chasers                    chasers-new-york-2
# 1823          Peggy Dempseys                peggy-dempseys-maspeth
# 1824   Club House Sports Bar  club-house-sports-bar-middle-village
#
#                           id  review_count  rating  \
# 0     ZTsN8TdMXl8SW_AKd_ablw           681     4.0
# 1     xiEBdZ8z5KY21Vw2pY2fJQ           662     4.0
# ...

# %%
bk_split.describe()
# Out:
#        review_count       rating
# count   1825.000000  1825.000000
# mean     245.039452     3.903836
# std      364.615008     0.644168
# min        1.000000     1.000000
# 25%       39.000000     3.500000
# 50%      127.000000     4.000000
# 75%      305.000000     4.500000
# max     3662.000000     5.000000

# %%
bk_split[bk_split['review_count'] > 20]
# Out:
#                               name                                    alias  \
# 0                      Forno Rosso                     forno-rosso-brooklyn
# 1           Two 8 Two Bar & Burger        two-8-two-bar-and-burger-brooklyn
# 2                   The River Café                the-river-café-brooklyn-3
# 3                          Colonie                         colonie-brooklyn
# 4                         Chez Moi                        chez-moi-brooklyn
# ...                            ...                                      ...
# 1818  Funfest Family Entertainment  funfest-family-entertainment-brooklyn-2
# 1819   Drunken Fish Sushi & Lounge  drunken-fish-sushi-and-lounge-ridgewood
# 1820                  The Live Oak                   the-live-oak-maspeth-2
# 1821              Knockdown Center                 knockdown-center-maspeth
# 1823                Peggy Dempseys                   peggy-dempseys-maspeth
#
#                           id  review_count  rating  \
# ...

# %%
bk_split = bk_split[bk_split['review_count'] > 20]

# %%
bk_split.reset_index(drop=True, inplace=True)

# %%
bk_split
# Out:
#                               name                                    alias  \
# 0                      Forno Rosso                     forno-rosso-brooklyn
# 1           Two 8 Two Bar & Burger        two-8-two-bar-and-burger-brooklyn
# 2                   The River Café                the-river-café-brooklyn-3
# 3                          Colonie                         colonie-brooklyn
# 4                         Chez Moi                        chez-moi-brooklyn
# ...                            ...                                      ...
# 1491  Funfest Family Entertainment  funfest-family-entertainment-brooklyn-2
# 1492   Drunken Fish Sushi & Lounge  drunken-fish-sushi-and-lounge-ridgewood
# 1493                  The Live Oak                   the-live-oak-maspeth-2
# 1494              Knockdown Center                 knockdown-center-maspeth
# 1495                Peggy Dempseys                   peggy-dempseys-maspeth
#
#                           id  review_count  rating  \
# ...

# %%
bk_split.to_csv('./brooklyn/final_bklyn_biz.csv', index=False)
