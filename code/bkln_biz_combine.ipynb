# %%
import numpy as np
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Cam\\Data Science\\DSI\\capstone'

# %%
os.chdir('./brooklyn/')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Cam\\Data Science\\DSI\\capstone\\brooklyn'

# %%
files = os.listdir()[1:]

# %%
files
# Out:
# ['brooklyn_11201.csv',
#  'brooklyn_11203.csv',
#  'brooklyn_11204.csv',
#  'brooklyn_11205.csv',
#  'brooklyn_11206.csv',
#  'brooklyn_11207.csv',
#  'brooklyn_11208.csv',
#  'brooklyn_11209.csv',
#  'brooklyn_11210.csv',
#  'brooklyn_11211.csv',
#  'brooklyn_11212.csv',
#  'brooklyn_11213.csv',
#  'brooklyn_11214.csv',
#  'brooklyn_11215.csv',
#  'brooklyn_11216.csv',
#  'brooklyn_11217.csv',
#  'brooklyn_11218.csv',
#  'brooklyn_11219.csv',
#  'brooklyn_11220.csv',
#  'brooklyn_11221.csv',
#  'brooklyn_11222.csv',
#  'brooklyn_11223.csv',
#  'brooklyn_11224.csv',
#  'brooklyn_11225.csv',
#  'brooklyn_11226.csv',
#  'brooklyn_11228.csv',
#  'brooklyn_11229.csv',
#  'brooklyn_11230.csv',
#  'brooklyn_11231.csv',
#  'brooklyn_11232.csv',
#  'brooklyn_11233.csv',
#  'brooklyn_11234.csv',
#  'brooklyn_11235.csv',
#  'brooklyn_11236.csv',
#  'brooklyn_11237.csv',
#  'brooklyn_11238.csv',
#  'brooklyn_11239.csv']

# %%
bk_bizs = [pd.read_csv(file) for file in files]

# %%
bk_bizs
# Out:
# [                         name                              alias  \
#  0                 Forno Rosso               forno-rosso-brooklyn
#  1      Two 8 Two Bar & Burger  two-8-two-bar-and-burger-brooklyn
#  2              The River Café          the-river-café-brooklyn-3
#  3                     Colonie                   colonie-brooklyn
#  4                    Chez Moi                  chez-moi-brooklyn
#  ..                        ...                                ...
#  317                  Rex Club                rex-club-new-york-2
#  318       Court Street Tavern       court-street-tavern-new-york
#  319  Nap TIme Liquid Creation  nap-time-liquid-creation-blauvelt
#  320                 Etiquette                 etiquette-brooklyn
#  321            601 Vanderbilt            601-vanderbilt-brooklyn
#
#                           id  review_count  rating  \
#  0    ZTsN8TdMXl8SW_AKd_ablw           681     4.0
#  1    xiEBdZ8z5KY21Vw2pY2fJQ           662     4.0
# ...

# %%
all_bk = pd.DataFrame()
for frame in bk_bizs:
    all_bk = all_bk.append(frame)
all_bk
# Out:
#                         name                                  alias  \
# 0                Forno Rosso                   forno-rosso-brooklyn
# 1     Two 8 Two Bar & Burger      two-8-two-bar-and-burger-brooklyn
# 2             The River Café              the-river-café-brooklyn-3
# 3                    Colonie                       colonie-brooklyn
# 4                   Chez Moi                      chez-moi-brooklyn
# ..                       ...                                    ...
# 57               Blue Iguana                   blue-iguana-brooklyn
# 58  Exotic Zone Bar & Lounge  exotic-zone-bar-and-lounge-ozone-park
# 59          Ooh La La Lounge         ooh-la-la-lounge-crown-heights
# 60            El Faro Lounge                el-faro-lounge-brooklyn
# 61    Blue Star Food & Paper      blue-star-food-and-paper-brooklyn
#
#                         id  review_count  rating  \
# 0   ZTsN8TdMXl8SW_AKd_ablw           681     4.0
# ...

# %%
all_bk.reset_index(inplace=True, drop=True)

# %%
all_bk
# Out:
#                           name                                  alias  \
# 0                  Forno Rosso                   forno-rosso-brooklyn
# 1       Two 8 Two Bar & Burger      two-8-two-bar-and-burger-brooklyn
# 2               The River Café              the-river-café-brooklyn-3
# 3                      Colonie                       colonie-brooklyn
# 4                     Chez Moi                      chez-moi-brooklyn
# ...                        ...                                    ...
# 5340               Blue Iguana                   blue-iguana-brooklyn
# 5341  Exotic Zone Bar & Lounge  exotic-zone-bar-and-lounge-ozone-park
# 5342          Ooh La La Lounge         ooh-la-la-lounge-crown-heights
# 5343            El Faro Lounge                el-faro-lounge-brooklyn
# 5344    Blue Star Food & Paper      blue-star-food-and-paper-brooklyn
#
#                           id  review_count  rating  \
# 0     ZTsN8TdMXl8SW_AKd_ablw           681     4.0
# ...

# %%
all_bk.columns
# Out:
# Index(['name', 'alias', 'id', 'review_count', 'rating', 'url', 'location',
#        'coordinates'],
#       dtype='object')

# %%
all_bk['id'].nunique()
# Out:
# 1825

# %%
all_bk['name'].nunique()
# Out:
# 1799

# %%
all_bk['alias'].nunique()
# Out:
# 1825

# %%
all_bk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5345 entries, 0 to 5344
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          5345 non-null   object
#  1   alias         5345 non-null   object
#  2   id            5345 non-null   object
#  3   review_count  5345 non-null   int64
#  4   rating        5345 non-null   float64
#  5   url           5345 non-null   object
#  6   location      5345 non-null   object
#  7   coordinates   5345 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 334.2+ KB

# %%
len(all_bk['id'].unique())
# Out:
# 1825

# %%
all_bk.drop_duplicates(subset='id', inplace = True)

# %%
all_bk['id'].nunique()
# Out:
# 1825

# %%
all_bk['name'].nunique()
# Out:
# 1799

# %%
all_bk['alias'].nunique()
# Out:
# 1825

# %%
all_bk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1825 entries, 0 to 4960
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          1825 non-null   object
#  1   alias         1825 non-null   object
#  2   id            1825 non-null   object
#  3   review_count  1825 non-null   int64
#  4   rating        1825 non-null   float64
#  5   url           1825 non-null   object
#  6   location      1825 non-null   object
#  7   coordinates   1825 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 128.3+ KB

# %%
len(all_bk['id'].unique())
# Out:
# 1825

# %%
all_bk
# Out:
#                         name                                 alias  \
# 0                Forno Rosso                  forno-rosso-brooklyn
# 1     Two 8 Two Bar & Burger     two-8-two-bar-and-burger-brooklyn
# 2             The River Café             the-river-café-brooklyn-3
# 3                    Colonie                      colonie-brooklyn
# 4                   Chez Moi                     chez-moi-brooklyn
# ...                      ...                                   ...
# 4891            The Live Oak                the-live-oak-maspeth-2
# 4903        Knockdown Center              knockdown-center-maspeth
# 4922                 Chasers                    chasers-new-york-2
# 4928          Peggy Dempseys                peggy-dempseys-maspeth
# 4960   Club House Sports Bar  club-house-sports-bar-middle-village
#
#                           id  review_count  rating  \
# 0     ZTsN8TdMXl8SW_AKd_ablw           681     4.0
# 1     xiEBdZ8z5KY21Vw2pY2fJQ           662     4.0
# ...

# %%
all_bk.reset_index(inplace = True, drop = True)

# %%
all_bk
# Out:
#                         name                                 alias  \
# 0                Forno Rosso                  forno-rosso-brooklyn
# 1     Two 8 Two Bar & Burger     two-8-two-bar-and-burger-brooklyn
# 2             The River Café             the-river-café-brooklyn-3
# 3                    Colonie                      colonie-brooklyn
# 4                   Chez Moi                     chez-moi-brooklyn
# ...                      ...                                   ...
# 1820            The Live Oak                the-live-oak-maspeth-2
# 1821        Knockdown Center              knockdown-center-maspeth
# 1822                 Chasers                    chasers-new-york-2
# 1823          Peggy Dempseys                peggy-dempseys-maspeth
# 1824   Club House Sports Bar  club-house-sports-bar-middle-village
#
#                           id  review_count  rating  \
# 0     ZTsN8TdMXl8SW_AKd_ablw           681     4.0
# 1     xiEBdZ8z5KY21Vw2pY2fJQ           662     4.0
# ...

# %%
all_bk.to_csv('all_bk_bizs.csv', index=False)
